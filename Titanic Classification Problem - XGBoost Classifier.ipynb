# %%
# GETTING THE DATASET

import pandas as pd
import numpy as np

df = pd.read_csv('/home/angel/Downloads/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_filtred = df.drop(['PassengerId', 'Survived', 'Name', 'Ticket'], axis=1)

# %%
df_filtred
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         3    male  22.0      1      0   7.2500   NaN        S
# 1         1  female  38.0      1      0  71.2833   C85        C
# 2         3  female  26.0      0      0   7.9250   NaN        S
# 3         1  female  35.0      1      0  53.1000  C123        S
# 4         3    male  35.0      0      0   8.0500   NaN        S
# ..      ...     ...   ...    ...    ...      ...   ...      ...
# 886       2    male  27.0      0      0  13.0000   NaN        S
# 887       1  female  19.0      0      0  30.0000   B42        S
# 888       3  female   NaN      1      2  23.4500   NaN        S
# 889       1    male  26.0      0      0  30.0000  C148        C
# 890       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 8 columns]

# %%
# At this point we start to preprocess the data

X = df_filtred
y = df['Survived'].to_numpy()

# %%
X['Sex'] = X['Sex'].map({'male': 1, 'female': 0})

# %%
X
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         3    1  22.0      1      0   7.2500   NaN        S
# 1         1    0  38.0      1      0  71.2833   C85        C
# 2         3    0  26.0      0      0   7.9250   NaN        S
# 3         1    0  35.0      1      0  53.1000  C123        S
# 4         3    1  35.0      0      0   8.0500   NaN        S
# ..      ...  ...   ...    ...    ...      ...   ...      ...
# 886       2    1  27.0      0      0  13.0000   NaN        S
# 887       1    0  19.0      0      0  30.0000   B42        S
# 888       3    0   NaN      1      2  23.4500   NaN        S
# 889       1    1  26.0      0      0  30.0000  C148        C
# 890       3    1  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 8 columns]

# %%
print(X['Embarked'].unique())
print(X['Cabin'].unique())
# Out:
# ['S' 'C' 'Q' nan]
# [nan 'C85' 'C123' 'E46' 'G6' 'C103' 'D56' 'A6' 'C23 C25 C27' 'B78' 'D33'
#  'B30' 'C52' 'B28' 'C83' 'F33' 'F G73' 'E31' 'A5' 'D10 D12' 'D26' 'C110'
#  'B58 B60' 'E101' 'F E69' 'D47' 'B86' 'F2' 'C2' 'E33' 'B19' 'A7' 'C49'
#  'F4' 'A32' 'B4' 'B80' 'A31' 'D36' 'D15' 'C93' 'C78' 'D35' 'C87' 'B77'
#  'E67' 'B94' 'C125' 'C99' 'C118' 'D7' 'A19' 'B49' 'D' 'C22 C26' 'C106'
#  'C65' 'E36' 'C54' 'B57 B59 B63 B66' 'C7' 'E34' 'C32' 'B18' 'C124' 'C91'
#  'E40' 'T' 'C128' 'D37' 'B35' 'E50' 'C82' 'B96 B98' 'E10' 'E44' 'A34'
#  'C104' 'C111' 'C92' 'E38' 'D21' 'E12' 'E63' 'A14' 'B37' 'C30' 'D20' 'B79'
#  'E25' 'D46' 'B73' 'C95' 'B38' 'B39' 'B22' 'C86' 'C70' 'A16' 'C101' 'C68'
#  'A10' 'E68' 'B41' 'A20' 'D19' 'D50' 'D9' 'A23' 'B50' 'A26' 'D48' 'E58'
#  'C126' 'B71' 'B51 B53 B55' 'D49' 'B5' 'B20' 'F G63' 'C62 C64' 'E24' 'C90'
#  'C45' 'E8' 'B101' 'D45' 'C46' 'D30' 'E121' 'D11' 'E77' 'F38' 'B3' 'D6'
#  'B82 B84' 'D17' 'A36' 'B102' 'B69' 'E49' 'C47' 'D28' 'E17' 'A24' 'C50'
# ...

# %%
len(X['Cabin'].unique())
# Out:
# 148

# %%
# Using an encoder

from sklearn.preprocessing import TargetEncoder

EmbEnc = TargetEncoder()
CabinEnc = TargetEncoder()

X_Cabin = pd.DataFrame(X['Cabin'])
X_Emb = pd.DataFrame(X['Embarked'])

CabinEnc.fit(X_Cabin, y)
EmbEnc.fit(X_Emb, y)

X_Cabin = CabinEnc.transform(X_Cabin)
X_Emb = EmbEnc.transform(X_Emb)

# %%
X['Cabin'] = X_Cabin
X['Embarked'] = X_Emb

# %%
X
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare     Cabin  Embarked
# 0         3    1  22.0      1      0   7.2500  0.299963  0.337025
# 1         1    0  38.0      1      0  71.2833  1.000000  0.552522
# 2         3    0  26.0      0      0   7.9250  0.299963  0.337025
# 3         1    0  35.0      1      0  53.1000  0.459834  0.337025
# 4         3    1  35.0      0      0   8.0500  0.299963  0.337025
# ..      ...  ...   ...    ...    ...      ...       ...       ...
# 886       2    1  27.0      0      0  13.0000  0.299963  0.337025
# 887       1    0  19.0      0      0  30.0000  1.000000  0.337025
# 888       3    0   NaN      1      2  23.4500  0.299963  0.337025
# 889       1    1  26.0      0      0  30.0000  1.000000  0.552522
# 890       3    1  32.0      0      0   7.7500  0.299963  0.389536
#
# [891 rows x 8 columns]

# %%
X.loc[X['Cabin'] == 1, 'Cabin'] = None

# %%
X
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare     Cabin  Embarked
# 0         3    1  22.0      1      0   7.2500  0.299963  0.337025
# 1         1    0  38.0      1      0  71.2833       NaN  0.552522
# 2         3    0  26.0      0      0   7.9250  0.299963  0.337025
# 3         1    0  35.0      1      0  53.1000  0.459834  0.337025
# 4         3    1  35.0      0      0   8.0500  0.299963  0.337025
# ..      ...  ...   ...    ...    ...      ...       ...       ...
# 886       2    1  27.0      0      0  13.0000  0.299963  0.337025
# 887       1    0  19.0      0      0  30.0000       NaN  0.337025
# 888       3    0   NaN      1      2  23.4500  0.299963  0.337025
# 889       1    1  26.0      0      0  30.0000       NaN  0.552522
# 890       3    1  32.0      0      0   7.7500  0.299963  0.389536
#
# [891 rows x 8 columns]

# %%
# I don't know if i should preprocess both Age and Fare features as well
    # Let's keep them as they are for now 

print(X['Age'].unique())
print(len(X['Age'].unique()))
print(end='\n\n')
print(X['Fare'].unique())
print(len(X['Fare'].unique()))
print(X['Parch'].unique())
print(len(X['Parch'].unique()))
print(end='\n\n')
print(X['SibSp'].unique())
print(len(X['SibSp'].unique()))
# Out:
# [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]
# 89
#
#
# [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55    31.275    7.8542  16.      29.125
#   13.      18.       7.225   26.       8.0292  35.5     31.3875 263.
#    7.8792   7.8958  27.7208 146.5208   7.75    10.5     82.1708  52.
#    7.2292  11.2417   9.475   21.      41.5792  15.5     21.6792  17.8
#   39.6875   7.8     76.7292  61.9792  27.75    46.9     80.      83.475
# ...

# %%
# We're going to take a deep look at the features

import matplotlib.pyplot as plt

plt.figure(figsize=(15,40))

plt.subplot(3,2,1)
plt.scatter(X.index, X['Fare'])

# %%
# Now we're ready to split the data into train-test sets

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, train_size=0.70, stratify=y)

# %%
X.index
# Out:
# RangeIndex(start=0, stop=891, step=1)
